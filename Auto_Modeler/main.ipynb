# %%
from preprocessing import preprocess_data
from hyperparameters_tuning import tune
from models import train_and_evaluate_models
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Path to your dataset and specify its taget column (in this dataset its "<=50k").
df_path = "data/dataset.csv"
target_column = "<=50k"

# %%
x_train, y_train, x_test, y_test = preprocess_data(df_path, target_column)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(x_train.corr(), cmap="coolwarm", annot=False)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (39072, 14)
# (39072,)
# (9769, 14)
# (9769,)

# %%
best_model_name, best_model, best_accuracy, results = train_and_evaluate_models(x_train, x_test, y_train, y_test)
# Out:
# C:\Users\mdanyalwahdat\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy: 0.8053
# Decision Tree Accuracy: 0.8084
# Random Forest Accuracy: 0.8568
# Support Vector Machine Accuracy: 0.7996
# Best model: Random Forest with accuracy 0.8568

# %%
best_params, tuned_acc = tune(best_model_name,x_train, x_test,y_train, y_test)
# Out:
# Params: {'n_estimators': 50} -> Accuracy: 0.8555
# Params: {'n_estimators': 100} -> Accuracy: 0.8567
# Params: {'n_estimators': 200} -> Accuracy: 0.8587

# %%
print(f"\nBest hyperparameters for {best_model_name}: {best_params}")
print(f"Accuracy after tuning: {tuned_acc:.4f}")
# Out:
# Best hyperparameters for Random Forest: {'n_estimators': 200}
# Accuracy after tuning: 0.8587
